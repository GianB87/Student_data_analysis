# %%
import os
import sys
import numpy as np
import pandas as pd
import openpyxl
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# UsageError: Line magic function `%%capture` not found.

# %% [markdown]
# # Limpieza de los datos
#
# Se trabaja con la data realizada en la encuesta universitaria

# %%
# funciones personalizadas
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21400/1838821372.py in <module>
#       3 if module_path not in sys.path:
#       4     sys.path.append(module_path)
# ----> 5 from utils.ipynb import *
#
# ModuleNotFoundError: No module named 'utils'

# %%
print(module_path)
# Out:
# C:\Users\giaan\Documents\Universidad\investigacion-docencia

# %%
# extract data
df = pd.read_excel('../data_student_satisfaction.xlsx')

# delete first row
df = df.iloc[1: , :] 
#df.apply(lambda x: ','.join(x.dropna()), axis=1)

# clean NaN and combine columns
df = five_question_columns_cleaner(df)


df = df[df.columns[2::]]

# %%
df = df.set_index('date_created').iloc[: , 6::]

# %%
df.describe()
# Out:
#        Puedo comprender en profundidad el contenido de los cursos del presente semestre.  \
# count                                         449.000000
# mean                                            3.104677
# std                                             1.352973
# min                                             0.000000
# 25%                                             3.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Puedo manejar los contenidos incluso en los cursos más avanzados.  \
# count                                         449.000000
# mean                                            3.008909
# std                                             1.380641
# min                                             0.000000
# 25%                                             2.000000
# 50%                                             3.000000
# ...

# %%
df.dtypes
# Out:
# DECLARACIÓN DE CONSENTIMIENTO: Declaro que los objetivos de esta investigación y todo lo relacionado con mi participación en ella me ha sido explicado claramente, que he leído y comprendido el contenido de este documento, y que estoy de acuerdo en participar en este estudio en las condiciones arriba expuestas     object
# Indique su edad:                                                                                                                                                                                                                                                                                                           object
# Indique el género con el cual se identifica:                                                                                                                                                                                                                                                                               object
# ...

# %%
for i in c0:
    print(type(i))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'float'>
# <class 'str'>
# <class 'float'>
# <class 'float'>
# <class 'str'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'str'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'str'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'str'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'str'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'str'>
# <class 'float'>
# <class 'float'>
# ...

# %%
c0
# Out:
# 0                                          respondent_id
# 1                                           collector_id
# 2                                           date_created
# 3                                          date_modified
# 4                                             ip_address
#                              ...
# 307    Mi nota final del curso, ¿en qué cuartil se en...
# 308                                                  NaN
# 309                                                  NaN
# 310                                                  NaN
# 311                                                  NaN
# Name: 0, Length: 312, dtype: object

# %%
columns = []
memory = ''
c0 = df.iloc[0]
c1 = df.iloc[1]
values = (c0,c1)
for index, i in enumerate(c0): 
    j = c1[index]
    if str(i) != 'nan' and str(j) != 'nan':
        columns.append(str(i) + '_' + str(j))
        memory = str(i)
    elif str(i) == 'nan' and str(j) != 'nan':
        columns.append(memory + '_' + str(j))
    else:
        columns.append(str(i))
source_col_loc = df.columns.get_loc('Column2') # column position starts from 0

df['ColumnA'] = df.iloc[:,source_col_loc+1:source_col_loc+4].apply(
    lambda x: ",".join(x.astype(str)), axis=1)

# %%
columns
# Out:
# ['respondent_id',
#  'collector_id',
#  'date_created',
#  'date_modified',
#  'ip_address',
#  'email_address',
#  'first_name',
#  'last_name',
#  'custom_1',
#  'DECLARACIÓN DE CONSENTIMIENTO: Declaro que los objetivos de esta investigación y todo lo relacionado con mi participación en ella me ha sido explicado claramente, que he leído y comprendido el contenido de este documento, y que estoy de acuerdo en participar en este estudio en las condiciones arriba expuestas_ACEPTO',
#  'DECLARACIÓN DE CONSENTIMIENTO: Declaro que los objetivos de esta investigación y todo lo relacionado con mi participación en ella me ha sido explicado claramente, que he leído y comprendido el contenido de este documento, y que estoy de acuerdo en participar en este estudio en las condiciones arriba expuestas_NO ACEPTO',
#  'Indique su edad:_Open-Ended Response',
#  'Indique el género con el cual se identifica:_Masculino',
#  'Indique el género con el cual se identifica:_Femenino',
# ...

# %%
df.columns[100:105]
# Out:
# Index(['Unnamed: 100', 'Unnamed: 101', 'Unnamed: 102', 'Unnamed: 103',
#        'Atento(a).'],
#       dtype='object')

# %%
df[df.columns[0:2]]
# Out:
#      respondent_id  collector_id
# 1     1.288161e+10   406335009.0
# 2     1.287839e+10   406335009.0
# 3     1.287289e+10   406335009.0
# 4     1.287158e+10   406335009.0
# 5     1.287155e+10   406335009.0
# ..             ...           ...
# 445   1.276640e+10   406335009.0
# 446   1.276406e+10   406335009.0
# 447   1.276407e+10   406335009.0
# 448   1.276158e+10   406335009.0
# 449   1.275592e+10   406335009.0
#
# [449 rows x 2 columns]
