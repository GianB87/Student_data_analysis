# %%
import os
import sys
import numpy as np
import pandas as pd
import openpyxl
import matplotlib.pyplot as plt
import seaborn as sns
import difflib
import statsmodels.api as sm
# %matplotlib inline

# %%
df = pd.read_excel('../data_proyect_research.xlsx')
df
# Out:
#                   Timestamp 1. He leído y acepto participar en la encuesta  \
# 0   2021-05-24 14:02:55.032                                             No
# 1   2021-05-24 15:15:55.813                                             Sí
# 2   2021-05-28 16:28:15.244                                             Sí
# 3   2021-05-29 11:51:54.785                                             Sí
# 4   2021-06-10 17:09:40.709                                             Sí
# ..                      ...                                            ...
# 588 2021-08-06 20:15:26.406                                             Sí
# 589 2021-08-06 22:48:44.619                                             Sí
# 590 2021-08-08 00:38:23.235                                             Sí
# 591 2021-08-08 15:44:29.638                                             Sí
# 592 2021-08-09 01:18:59.268                                             Sí
#
# ...
